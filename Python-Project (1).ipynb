# %% [markdown]
# # **Python Project**

# %% [markdown]
# ## Introduction
# ### The California Dataset gives a description about the california housing data and the dataset consists of the following features:
# ### 1) longitude : The datatype is numerical and this is a Continuous data
# ### 2) latitude: The datatype is numerical and this also is a Continuous data
# ### 3) housing_median_age : Quantitative type - Discrete data
# ### 4) total_rooms : Quantitative type - Discrete data
# ### 5) total_bedrooms : Quantitative type - Discrete data
# ### 6) population : Quantitative type - Discrete data
# ### 7) households : Quantitative type - Discrete data
# ### 8) median_income : Quantitative type - Continuous data
# ### 9) median_house_value : Quantitative type - Discrete data
# ### 10) ocean_proximity : Qualitative type- Nominal data

# %%
# Importing all the required libraries
# np is for numerical calculations
import numpy as np
# pd is for data manipulation and analysis  
import pandas as pd
# plt and sns are for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data = pd.read_excel("C:\\Users\\joshcj\\Downloads\\housing+(1).xlsx") # loading our data into the variable raw_data

# %%
raw_data.head() # displaying the first 5 rows of the data to understand the california dataset
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
raw_data.dtypes # data types of each column
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
raw_data.shape # shape of the dataset -- we have 20640 rows and 10 columns
# Out:
# (20640, 10)

# %%
raw_data.describe() # we can see that there are missing values in the total_bedrooms column
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
raw_data.info() # concise summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
raw_data['median_income'].mean() # average median income
# Out:
# 3.8706710029069766

# %%
# Histogram is used for seeing the distribution of numerical data 
raw_data.hist(bins = 30,figsize=(20,20)) 
plt.show()
sns.set()

# %% [markdown]
# longitude and latitude are asymmetric(highly skewed) while total_rooms,total_bedrooms,population,households,median_income and median_house_value are Right skewed and outlier is present in housing_median_age and  median_house_value

# %% [markdown]
# ### 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
sns.histplot(data = raw_data['housing_median_age'],color ='green' ) 
plt.title('Distribution of housing median age')
plt.xlabel('housing_median_age')
plt.grid(True)
plt.show()

# %% [markdown]
# #### From the plot above, we can say that it is distributed symmetrically  but there is an outlier at the end

# %%
raw_data['housing_median_age'].skew()# the skewness is almost 0, hence it is symmetric
# Out:
# 0.060330637599136865

# %% [markdown]
# ### 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
# scatter plot are used to observe relationships between numeric variables.
sns.scatterplot(data = raw_data, x = 'median_house_value', y = 'median_income',color = '#FF3333' )
plt.xlabel('median_house_value')
plt.ylabel('median_income')
plt.title('Relationship between median_income and median_house_values')
sns.set_style('dark')
plt.show()

# %% [markdown]
# #### From the figure,we can say that there is a positive correlation between median_house_value and median_income and also there is an outlier.

# %% [markdown]
# ### 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
raw_data['total_bedrooms'].isnull().sum() # Total null values in the column
# Out:
# 207

# %%
# dropna function is used to remove the null values
new_data = raw_data.dropna(subset = 'total_bedrooms')

# %%
new_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
new_data['total_bedrooms'].isnull().sum() # Null values have been dropped
# Out:
# 0

# %% [markdown]
# ### 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
# mean is used to calculate the average
tb_mean = raw_data['total_bedrooms'].mean()
print(tb_mean)
# Out:
# 537.8705525375618

# %%
# fillna is used to replace null values and here we are replacing null values with the mean
raw_data['total_bedrooms'] = raw_data['total_bedrooms'] .fillna(tb_mean)

# %%
raw_data['total_bedrooms'].isnull().sum()
# Out:
# 0

# %%
raw_data['total_bedrooms'].describe()
# Out:
# count    20640.000000
# mean       537.870553
# std        419.266592
# min          1.000000
# 25%        297.000000
# 50%        438.000000
# 75%        643.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# ### 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
def med(feature):
    value = raw_data[feature].median()
    return value

cols = list(raw_data.columns)
col = cols[:-1]
for ele in col:
    print(f'{ele} median is:',med(ele))
# Out:
# longitude median is: -118.49
# latitude median is: 34.26
# housing_median_age median is: 29.0
# total_rooms median is: 2127.0
# total_bedrooms median is: 438.0
# population median is: 1166.0
# households median is: 409.0
# median_income median is: 3.5347999999999997
# median_house_value median is: 179700.0

# %% [markdown]
# ### 7. Plot latitude versus longitude and explain your observations.

# %%
sns.scatterplot(data = raw_data, x = 'latitude', y = 'longitude',color = 'green' )
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('latitude versus longitude')
sns.set_style('white')
plt.show()

# %% [markdown]
# #### We can say that there is a negative correlation between the two and they are inversely proportional to each other

# %% [markdown]
# ### 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
# loc is used to access a group of rows and columns by label(s).
ocean = raw_data.loc[raw_data['ocean_proximity'] == 'NEAR OCEAN']

# %%
ocean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %%
# value_counts is used to get the counts of unique rows in the DataFrame
raw_data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### 9. Find the mean and median of the median income for the data set created in question 8.

# %%
ocean['median_income'].mean()
# Out:
# 4.0057848006019565

# %%
ocean['median_income'].median()
# Out:
# 3.64705

# %% [markdown]
# ### 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
raw_data.loc[raw_data['total_bedrooms'] <= 10,'total_bedroom_size'] = 'small'
raw_data.loc[(raw_data['total_bedrooms'] >= 11) & (raw_data['total_bedrooms'] < 1000),'total_bedroom_size'] = 'medium'
raw_data.loc[raw_data['total_bedrooms'] >= 1000,'total_bedroom_size'] = 'large'

# %%
raw_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
raw_data['total_bedroom_size'].value_counts()
# Out:
# medium    18702
# large      1883
# small        55
# Name: total_bedroom_size, dtype: int64
